# %% [markdown]
# # Exercise 5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def step():
    import random
    return 1. if random.random() > .5 else -1.

# %%
def walk(n):
    x = np.zeros(n)
    dx = 1. / n
    for i in range(n - 1):
        x_new = x[i] + dx * step()
        if x_new > 5e-3:
            x[i + 1] = 0.
        else:
            x[i + 1] = x_new
    return x

# %%
# %%prun
n = 100000
x = walk(n)
t1 = %timeit -o walk(n)
plt.plot(x)
# Out:
# 64.1 ms ± 382 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)
#          16422374 function calls (16422074 primitive calls) in 5.296 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        82    3.005    0.037    5.277    0.064 2505900611.py:1(walk)
#   8199918    1.889    0.000    2.268    0.000 3033770663.py:1(step)
#   8199918    0.379    0.000    0.379    0.000 {method 'random' of '_random.Random' objects}
#        82    0.005    0.000    0.005    0.000 {built-in method numpy.zeros}
#         9    0.001    0.000    5.197    0.577 <magic-timeit>:1(inner)
#         1    0.001    0.001    0.001    0.001 {built-in method matplotlib._path.update_path_extents}
#       149    0.001    0.000    0.002    0.000 artist.py:1176(_update_props)
#         2    0.001    0.000    0.001    0.000 {method '__copy__' of 'numpy.ndarray' objects}
#       127    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
# ...
