# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Что происходит без `requirements.txt`?
# При рассмотрении блокнота 'fig3bc.ipynb` в репозитории неравенства действий. (https://github.com/timalthoff/activityinequality), начало кода (импорт модулей) выходит в ошибку:

# %%
# !python -m pip install -r requirements.txt
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid") 
from itertools import cycle
# Out:
# Requirement already satisfied: matplotlib in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (3.9.2)
# Requirement already satisfied: pandas in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: seaborn in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Создаем в том же репозитории, где хранится данный ноутбук, файл `requirements.txt`, который будет содержать все необходимые для работы модули:
#
# ![png2.png](attachment:png2.png)

# %% [markdown]
# Так как выдаёт ошибку, пробуем установить Python модули

# %%
# !python -m pip install pandas seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: seaborn in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\виктория\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# Проверяем, работает ли наш текстовый файл. Для этого добавляем в начало исходного кода строку:
#
# !python -m pip install -r requirements.txt
#
# Версии используемых модулей:
# 1) Pandas(2.2.3)
# 2) Matplotlib(3.9.2)
# 3) Seaborn(0.13.2)
